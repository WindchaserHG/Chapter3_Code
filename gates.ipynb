# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import numpy as np
import random
from exp.exp_anomaly_detection import Exp_Anomaly_Detection
import argparse
import time
import torch.nn as nn
import math

import torch.fft as fft
from einops import rearrange, reduce, repeat

# %matplotlib inline

# %%
class moving_avg(nn.Module):
    """
    Moving average block to highlight the trend of time series
    """

    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        # padding on the both ends of time series
        front = x[:, 0:1, :].repeat(1, self.kernel_size - 1 - math.floor((self.kernel_size - 1) // 2), 1)
        end = x[:, -1:, :].repeat(1, math.floor((self.kernel_size - 1) // 2), 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x

class series_decomp_multi(nn.Module):
    """
    Series decomposition block
    """

    def __init__(self, kernel_size):
        super(series_decomp_multi, self).__init__()
        self.moving_avg = [moving_avg(kernel, stride=1) for kernel in kernel_size]
        self.layer = torch.nn.Linear(1, len(kernel_size))

    def forward(self, x):
        moving_mean = []
        for func in self.moving_avg:
            moving_avg = func(x)
            moving_mean.append(moving_avg.unsqueeze(-1))
        moving_mean = torch.cat(moving_mean, dim=-1)
        moving_mean = torch.sum(moving_mean * nn.Softmax(-1)(self.layer(x.unsqueeze(-1))), dim=-1)
        res = x - moving_mean
        return res, moving_mean

# %%
checkpoint  = torch.load("checkpoints/dataset_re_bs128_sl96_dm16_df16_ln3_k2_embtimeF_ar20.0_lr1e-05_pt20_te50_bn1_0/checkpoint.pth")
# 如果 checkpoint 是 state_dict  
state_dict = checkpoint['state_dict'] if 'state_dict' in checkpoint else checkpoint

# %%
# 打印所有参数名称，帮助确认命名结构  
print("All parameters in the state_dict:")  
for param_name in state_dict.keys():  
    print(param_name)
# AMS_lists.2.trend_model.layer.weight
# AMS_lists.2.trend_model.layer.bias
print("\nExtracting trend_model parameters:")  

# 提取线性层的参数（假设在模型中它被命名为 layer）
weight = state_dict["AMS_lists.2.trend_model.layer.weight"]
print("Linear Layer Weight:")  
print(weight)

bias = state_dict["AMS_lists.2.trend_model.layer.bias"]
print("Linear Layer Bias:")
print(bias)
# Out:
# All parameters in the state_dict:
# start_fc.weight
# start_fc.bias
# AMS_lists.0.mean
# AMS_lists.0.std
# AMS_lists.0.start_linear.weight
# AMS_lists.0.start_linear.bias
# AMS_lists.0.trend_model.layer.weight
# AMS_lists.0.trend_model.layer.bias
# AMS_lists.0.experts.0.intra_embeddings
# AMS_lists.0.experts.0.W_pos
# AMS_lists.0.experts.0.embeddings_generator.0.0.weight
# AMS_lists.0.experts.0.embeddings_generator.0.0.bias
# AMS_lists.0.experts.0.embeddings_generator.1.0.weight
# AMS_lists.0.experts.0.embeddings_generator.1.0.bias
# AMS_lists.0.experts.0.embeddings_generator.2.0.weight
# AMS_lists.0.experts.0.embeddings_generator.2.0.bias
# AMS_lists.0.experts.0.embeddings_generator.3.0.weight
# AMS_lists.0.experts.0.embeddings_generator.3.0.bias
# AMS_lists.0.experts.0.embeddings_generator.4.0.weight
# AMS_lists.0.experts.0.embeddings_generator.4.0.bias
# AMS_lists.0.experts.0.embeddings_generator.5.0.weight
# AMS_lists.0.experts.0.embeddings_generator.5.0.bias
# AMS_lists.0.experts.0.weights_generator_distinct.memory
# AMS_lists.0.experts.0.weights_generator_distinct.generator.0.weight
# AMS_lists.0.experts.0.weights_generator_distinct.generator.0.bias
# AMS_lists.0.experts.0.weights_generator_distinct.generator.2.weight
# AMS_lists.0.experts.0.weights_generator_distinct.generator.2.bias
# AMS_lists.0.experts.0.weights_generator_distinct.generator.4.weight
# AMS_lists.0.experts.0.weights_generator_distinct.generator.4.bias
# AMS_lists.0.experts.0.weights_generator_distinct.P.0
# AMS_lists.0.experts.0.weights_generator_distinct.P.1
# AMS_lists.0.experts.0.weights_generator_distinct.Q.0
# AMS_lists.0.experts.0.weights_generator_distinct.Q.1
# AMS_lists.0.experts.0.weights_generator_distinct.B.0
# AMS_lists.0.experts.0.weights_generator_distinct.B.1
# AMS_lists.0.experts.0.weights_generator_shared.P.0
# AMS_lists.0.experts.0.weights_generator_shared.P.1
# AMS_lists.0.experts.0.weights_generator_shared.B.0
# AMS_lists.0.experts.0.weights_generator_shared.B.1
# AMS_lists.0.experts.0.intra_Linear.weight
# AMS_lists.0.experts.0.intra_Linear.bias
# AMS_lists.0.experts.0.emb_linear.weight
# AMS_lists.0.experts.0.emb_linear.bias
# AMS_lists.0.experts.0.inter_patch_attention.W_Q.weight
# AMS_lists.0.experts.0.inter_patch_attention.W_Q.bias
# AMS_lists.0.experts.0.inter_patch_attention.W_K.weight
# AMS_lists.0.experts.0.inter_patch_attention.W_K.bias
# AMS_lists.0.experts.0.inter_patch_attention.W_V.weight
# AMS_lists.0.experts.0.inter_patch_attention.W_V.bias
# AMS_lists.0.experts.0.inter_patch_attention.sdp_attn.scale
# AMS_lists.0.experts.0.inter_patch_attention.to_out.0.weight
# AMS_lists.0.experts.0.inter_patch_attention.to_out.0.bias
# AMS_lists.0.experts.0.norm_attn.1.weight
# AMS_lists.0.experts.0.norm_attn.1.bias
# AMS_lists.0.experts.0.norm_attn.1.running_mean
# AMS_lists.0.experts.0.norm_attn.1.running_var
# AMS_lists.0.experts.0.norm_attn.1.num_batches_tracked
# AMS_lists.0.experts.0.norm_ffn.1.weight
# AMS_lists.0.experts.0.norm_ffn.1.bias
# AMS_lists.0.experts.0.norm_ffn.1.running_mean
# AMS_lists.0.experts.0.norm_ffn.1.running_var
# AMS_lists.0.experts.0.norm_ffn.1.num_batches_tracked
# AMS_lists.0.experts.0.ff.0.weight
# AMS_lists.0.experts.0.ff.0.bias
# AMS_lists.0.experts.0.ff.3.weight
# AMS_lists.0.experts.0.ff.3.bias
# AMS_lists.0.experts.1.intra_embeddings
# AMS_lists.0.experts.1.W_pos
# AMS_lists.0.experts.1.embeddings_generator.0.0.weight
# AMS_lists.0.experts.1.embeddings_generator.0.0.bias
# AMS_lists.0.experts.1.embeddings_generator.1.0.weight
# AMS_lists.0.experts.1.embeddings_generator.1.0.bias
# AMS_lists.0.experts.1.embeddings_generator.2.0.weight
# AMS_lists.0.experts.1.embeddings_generator.2.0.bias
# AMS_lists.0.experts.1.embeddings_generator.3.0.weight
# AMS_lists.0.experts.1.embeddings_generator.3.0.bias
# AMS_lists.0.experts.1.embeddings_generator.4.0.weight
# AMS_lists.0.experts.1.embeddings_generator.4.0.bias
# AMS_lists.0.experts.1.embeddings_generator.5.0.weight
# AMS_lists.0.experts.1.embeddings_generator.5.0.bias
# AMS_lists.0.experts.1.embeddings_generator.6.0.weight
# AMS_lists.0.experts.1.embeddings_generator.6.0.bias
# AMS_lists.0.experts.1.embeddings_generator.7.0.weight
# AMS_lists.0.experts.1.embeddings_generator.7.0.bias
# AMS_lists.0.experts.1.weights_generator_distinct.memory
# AMS_lists.0.experts.1.weights_generator_distinct.generator.0.weight
# AMS_lists.0.experts.1.weights_generator_distinct.generator.0.bias
# AMS_lists.0.experts.1.weights_generator_distinct.generator.2.weight
# AMS_lists.0.experts.1.weights_generator_distinct.generator.2.bias
# AMS_lists.0.experts.1.weights_generator_distinct.generator.4.weight
# AMS_lists.0.experts.1.weights_generator_distinct.generator.4.bias
# AMS_lists.0.experts.1.weights_generator_distinct.P.0
# AMS_lists.0.experts.1.weights_generator_distinct.P.1
# AMS_lists.0.experts.1.weights_generator_distinct.Q.0
# AMS_lists.0.experts.1.weights_generator_distinct.Q.1
# AMS_lists.0.experts.1.weights_generator_distinct.B.0
# AMS_lists.0.experts.1.weights_generator_distinct.B.1
# AMS_lists.0.experts.1.weights_generator_shared.P.0
# AMS_lists.0.experts.1.weights_generator_shared.P.1
# AMS_lists.0.experts.1.weights_generator_shared.B.0
# AMS_lists.0.experts.1.weights_generator_shared.B.1
# AMS_lists.0.experts.1.intra_Linear.weight
# AMS_lists.0.experts.1.intra_Linear.bias
# AMS_lists.0.experts.1.emb_linear.weight
# AMS_lists.0.experts.1.emb_linear.bias
# AMS_lists.0.experts.1.inter_patch_attention.W_Q.weight
# AMS_lists.0.experts.1.inter_patch_attention.W_Q.bias
# AMS_lists.0.experts.1.inter_patch_attention.W_K.weight
# AMS_lists.0.experts.1.inter_patch_attention.W_K.bias
# AMS_lists.0.experts.1.inter_patch_attention.W_V.weight
# AMS_lists.0.experts.1.inter_patch_attention.W_V.bias
# AMS_lists.0.experts.1.inter_patch_attention.sdp_attn.scale
# AMS_lists.0.experts.1.inter_patch_attention.to_out.0.weight
# AMS_lists.0.experts.1.inter_patch_attention.to_out.0.bias
# AMS_lists.0.experts.1.norm_attn.1.weight
# AMS_lists.0.experts.1.norm_attn.1.bias
# AMS_lists.0.experts.1.norm_attn.1.running_mean
# AMS_lists.0.experts.1.norm_attn.1.running_var
# AMS_lists.0.experts.1.norm_attn.1.num_batches_tracked
# AMS_lists.0.experts.1.norm_ffn.1.weight
# AMS_lists.0.experts.1.norm_ffn.1.bias
# AMS_lists.0.experts.1.norm_ffn.1.running_mean
# AMS_lists.0.experts.1.norm_ffn.1.running_var
# AMS_lists.0.experts.1.norm_ffn.1.num_batches_tracked
# AMS_lists.0.experts.1.ff.0.weight
# AMS_lists.0.experts.1.ff.0.bias
# AMS_lists.0.experts.1.ff.3.weight
# AMS_lists.0.experts.1.ff.3.bias
# AMS_lists.0.experts.2.intra_embeddings
# AMS_lists.0.experts.2.W_pos
# AMS_lists.0.experts.2.embeddings_generator.0.0.weight
# AMS_lists.0.experts.2.embeddings_generator.0.0.bias
# AMS_lists.0.experts.2.embeddings_generator.1.0.weight
# AMS_lists.0.experts.2.embeddings_generator.1.0.bias
# AMS_lists.0.experts.2.embeddings_generator.2.0.weight
# AMS_lists.0.experts.2.embeddings_generator.2.0.bias
# AMS_lists.0.experts.2.embeddings_generator.3.0.weight
# AMS_lists.0.experts.2.embeddings_generator.3.0.bias
# AMS_lists.0.experts.2.embeddings_generator.4.0.weight
# AMS_lists.0.experts.2.embeddings_generator.4.0.bias
# AMS_lists.0.experts.2.embeddings_generator.5.0.weight
# AMS_lists.0.experts.2.embeddings_generator.5.0.bias
# AMS_lists.0.experts.2.embeddings_generator.6.0.weight
# AMS_lists.0.experts.2.embeddings_generator.6.0.bias
# AMS_lists.0.experts.2.embeddings_generator.7.0.weight
# AMS_lists.0.experts.2.embeddings_generator.7.0.bias
# AMS_lists.0.experts.2.embeddings_generator.8.0.weight
# AMS_lists.0.experts.2.embeddings_generator.8.0.bias
# AMS_lists.0.experts.2.embeddings_generator.9.0.weight
# AMS_lists.0.experts.2.embeddings_generator.9.0.bias
# AMS_lists.0.experts.2.embeddings_generator.10.0.weight
# AMS_lists.0.experts.2.embeddings_generator.10.0.bias
# AMS_lists.0.experts.2.embeddings_generator.11.0.weight
# AMS_lists.0.experts.2.embeddings_generator.11.0.bias
# AMS_lists.0.experts.2.weights_generator_distinct.memory
# AMS_lists.0.experts.2.weights_generator_distinct.generator.0.weight
# AMS_lists.0.experts.2.weights_generator_distinct.generator.0.bias
# AMS_lists.0.experts.2.weights_generator_distinct.generator.2.weight
# AMS_lists.0.experts.2.weights_generator_distinct.generator.2.bias
# AMS_lists.0.experts.2.weights_generator_distinct.generator.4.weight
# AMS_lists.0.experts.2.weights_generator_distinct.generator.4.bias
# AMS_lists.0.experts.2.weights_generator_distinct.P.0
# AMS_lists.0.experts.2.weights_generator_distinct.P.1
# AMS_lists.0.experts.2.weights_generator_distinct.Q.0
# AMS_lists.0.experts.2.weights_generator_distinct.Q.1
# AMS_lists.0.experts.2.weights_generator_distinct.B.0
# AMS_lists.0.experts.2.weights_generator_distinct.B.1
# AMS_lists.0.experts.2.weights_generator_shared.P.0
# AMS_lists.0.experts.2.weights_generator_shared.P.1
# AMS_lists.0.experts.2.weights_generator_shared.B.0
# AMS_lists.0.experts.2.weights_generator_shared.B.1
# AMS_lists.0.experts.2.intra_Linear.weight
# AMS_lists.0.experts.2.intra_Linear.bias
# AMS_lists.0.experts.2.emb_linear.weight
# AMS_lists.0.experts.2.emb_linear.bias
# AMS_lists.0.experts.2.inter_patch_attention.W_Q.weight
# AMS_lists.0.experts.2.inter_patch_attention.W_Q.bias
# AMS_lists.0.experts.2.inter_patch_attention.W_K.weight
# AMS_lists.0.experts.2.inter_patch_attention.W_K.bias
# AMS_lists.0.experts.2.inter_patch_attention.W_V.weight
# AMS_lists.0.experts.2.inter_patch_attention.W_V.bias
# AMS_lists.0.experts.2.inter_patch_attention.sdp_attn.scale
# AMS_lists.0.experts.2.inter_patch_attention.to_out.0.weight
# AMS_lists.0.experts.2.inter_patch_attention.to_out.0.bias
# AMS_lists.0.experts.2.norm_attn.1.weight
# AMS_lists.0.experts.2.norm_attn.1.bias
# AMS_lists.0.experts.2.norm_attn.1.running_mean
# AMS_lists.0.experts.2.norm_attn.1.running_var
# AMS_lists.0.experts.2.norm_attn.1.num_batches_tracked
# AMS_lists.0.experts.2.norm_ffn.1.weight
# AMS_lists.0.experts.2.norm_ffn.1.bias
# AMS_lists.0.experts.2.norm_ffn.1.running_mean
# AMS_lists.0.experts.2.norm_ffn.1.running_var
# AMS_lists.0.experts.2.norm_ffn.1.num_batches_tracked
# AMS_lists.0.experts.2.ff.0.weight
# AMS_lists.0.experts.2.ff.0.bias
# AMS_lists.0.experts.2.ff.3.weight
# AMS_lists.0.experts.2.ff.3.bias
# AMS_lists.0.experts.3.intra_embeddings
# AMS_lists.0.experts.3.W_pos
# AMS_lists.0.experts.3.embeddings_generator.0.0.weight
# AMS_lists.0.experts.3.embeddings_generator.0.0.bias
# AMS_lists.0.experts.3.embeddings_generator.1.0.weight
# AMS_lists.0.experts.3.embeddings_generator.1.0.bias
# AMS_lists.0.experts.3.embeddings_generator.2.0.weight
# AMS_lists.0.experts.3.embeddings_generator.2.0.bias
# AMS_lists.0.experts.3.weights_generator_distinct.memory
# AMS_lists.0.experts.3.weights_generator_distinct.generator.0.weight
# AMS_lists.0.experts.3.weights_generator_distinct.generator.0.bias
# AMS_lists.0.experts.3.weights_generator_distinct.generator.2.weight
# AMS_lists.0.experts.3.weights_generator_distinct.generator.2.bias
# AMS_lists.0.experts.3.weights_generator_distinct.generator.4.weight
# AMS_lists.0.experts.3.weights_generator_distinct.generator.4.bias
# AMS_lists.0.experts.3.weights_generator_distinct.P.0
# AMS_lists.0.experts.3.weights_generator_distinct.P.1
# AMS_lists.0.experts.3.weights_generator_distinct.Q.0
# AMS_lists.0.experts.3.weights_generator_distinct.Q.1
# AMS_lists.0.experts.3.weights_generator_distinct.B.0
# AMS_lists.0.experts.3.weights_generator_distinct.B.1
# AMS_lists.0.experts.3.weights_generator_shared.P.0
# AMS_lists.0.experts.3.weights_generator_shared.P.1
# AMS_lists.0.experts.3.weights_generator_shared.B.0
# AMS_lists.0.experts.3.weights_generator_shared.B.1
# AMS_lists.0.experts.3.intra_Linear.weight
# AMS_lists.0.experts.3.intra_Linear.bias
# AMS_lists.0.experts.3.emb_linear.weight
# AMS_lists.0.experts.3.emb_linear.bias
# AMS_lists.0.experts.3.inter_patch_attention.W_Q.weight
# AMS_lists.0.experts.3.inter_patch_attention.W_Q.bias
# AMS_lists.0.experts.3.inter_patch_attention.W_K.weight
# AMS_lists.0.experts.3.inter_patch_attention.W_K.bias
# AMS_lists.0.experts.3.inter_patch_attention.W_V.weight
# AMS_lists.0.experts.3.inter_patch_attention.W_V.bias
# AMS_lists.0.experts.3.inter_patch_attention.sdp_attn.scale
# AMS_lists.0.experts.3.inter_patch_attention.to_out.0.weight
# AMS_lists.0.experts.3.inter_patch_attention.to_out.0.bias
# AMS_lists.0.experts.3.norm_attn.1.weight
# AMS_lists.0.experts.3.norm_attn.1.bias
# AMS_lists.0.experts.3.norm_attn.1.running_mean
# AMS_lists.0.experts.3.norm_attn.1.running_var
# AMS_lists.0.experts.3.norm_attn.1.num_batches_tracked
# AMS_lists.0.experts.3.norm_ffn.1.weight
# AMS_lists.0.experts.3.norm_ffn.1.bias
# AMS_lists.0.experts.3.norm_ffn.1.running_mean
# AMS_lists.0.experts.3.norm_ffn.1.running_var
# AMS_lists.0.experts.3.norm_ffn.1.num_batches_tracked
# AMS_lists.0.experts.3.ff.0.weight
# AMS_lists.0.experts.3.ff.0.bias
# AMS_lists.0.experts.3.ff.3.weight
# AMS_lists.0.experts.3.ff.3.bias
# AMS_lists.0.w_noise.weight
# AMS_lists.0.w_noise.bias
# AMS_lists.0.w_noise_norm.weight
# AMS_lists.0.w_noise_norm.bias
# AMS_lists.0.w_gate.weight
# AMS_lists.0.w_gate.bias
# AMS_lists.0.w_gate_norm.weight
# AMS_lists.0.w_gate_norm.bias
# AMS_lists.0.end_MLP.fc.weight
# AMS_lists.0.end_MLP.fc.bias
# AMS_lists.1.mean
# AMS_lists.1.std
# AMS_lists.1.start_linear.weight
# AMS_lists.1.start_linear.bias
# AMS_lists.1.trend_model.layer.weight
# AMS_lists.1.trend_model.layer.bias
# AMS_lists.1.experts.0.intra_embeddings
# AMS_lists.1.experts.0.W_pos
# AMS_lists.1.experts.0.embeddings_generator.0.0.weight
# AMS_lists.1.experts.0.embeddings_generator.0.0.bias
# AMS_lists.1.experts.0.embeddings_generator.1.0.weight
# AMS_lists.1.experts.0.embeddings_generator.1.0.bias
# AMS_lists.1.experts.0.embeddings_generator.2.0.weight
# AMS_lists.1.experts.0.embeddings_generator.2.0.bias
# AMS_lists.1.experts.0.embeddings_generator.3.0.weight
# AMS_lists.1.experts.0.embeddings_generator.3.0.bias
# AMS_lists.1.experts.0.embeddings_generator.4.0.weight
# AMS_lists.1.experts.0.embeddings_generator.4.0.bias
# AMS_lists.1.experts.0.embeddings_generator.5.0.weight
# AMS_lists.1.experts.0.embeddings_generator.5.0.bias
# AMS_lists.1.experts.0.embeddings_generator.6.0.weight
# AMS_lists.1.experts.0.embeddings_generator.6.0.bias
# AMS_lists.1.experts.0.embeddings_generator.7.0.weight
# AMS_lists.1.experts.0.embeddings_generator.7.0.bias
# AMS_lists.1.experts.0.weights_generator_distinct.memory
# AMS_lists.1.experts.0.weights_generator_distinct.generator.0.weight
# AMS_lists.1.experts.0.weights_generator_distinct.generator.0.bias
# AMS_lists.1.experts.0.weights_generator_distinct.generator.2.weight
# AMS_lists.1.experts.0.weights_generator_distinct.generator.2.bias
# AMS_lists.1.experts.0.weights_generator_distinct.generator.4.weight
# AMS_lists.1.experts.0.weights_generator_distinct.generator.4.bias
# AMS_lists.1.experts.0.weights_generator_distinct.P.0
# AMS_lists.1.experts.0.weights_generator_distinct.P.1
# AMS_lists.1.experts.0.weights_generator_distinct.Q.0
# AMS_lists.1.experts.0.weights_generator_distinct.Q.1
# AMS_lists.1.experts.0.weights_generator_distinct.B.0
# AMS_lists.1.experts.0.weights_generator_distinct.B.1
# AMS_lists.1.experts.0.weights_generator_shared.P.0
# AMS_lists.1.experts.0.weights_generator_shared.P.1
# AMS_lists.1.experts.0.weights_generator_shared.B.0
# AMS_lists.1.experts.0.weights_generator_shared.B.1
# AMS_lists.1.experts.0.intra_Linear.weight
# AMS_lists.1.experts.0.intra_Linear.bias
# AMS_lists.1.experts.0.emb_linear.weight
# AMS_lists.1.experts.0.emb_linear.bias
# AMS_lists.1.experts.0.inter_patch_attention.W_Q.weight
# AMS_lists.1.experts.0.inter_patch_attention.W_Q.bias
# AMS_lists.1.experts.0.inter_patch_attention.W_K.weight
# AMS_lists.1.experts.0.inter_patch_attention.W_K.bias
# AMS_lists.1.experts.0.inter_patch_attention.W_V.weight
# AMS_lists.1.experts.0.inter_patch_attention.W_V.bias
# AMS_lists.1.experts.0.inter_patch_attention.sdp_attn.scale
# AMS_lists.1.experts.0.inter_patch_attention.to_out.0.weight
# AMS_lists.1.experts.0.inter_patch_attention.to_out.0.bias
# AMS_lists.1.experts.0.norm_attn.1.weight
# AMS_lists.1.experts.0.norm_attn.1.bias
# AMS_lists.1.experts.0.norm_attn.1.running_mean
# AMS_lists.1.experts.0.norm_attn.1.running_var
# AMS_lists.1.experts.0.norm_attn.1.num_batches_tracked
# AMS_lists.1.experts.0.norm_ffn.1.weight
# AMS_lists.1.experts.0.norm_ffn.1.bias
# AMS_lists.1.experts.0.norm_ffn.1.running_mean
# AMS_lists.1.experts.0.norm_ffn.1.running_var
# AMS_lists.1.experts.0.norm_ffn.1.num_batches_tracked
# AMS_lists.1.experts.0.ff.0.weight
# AMS_lists.1.experts.0.ff.0.bias
# AMS_lists.1.experts.0.ff.3.weight
# AMS_lists.1.experts.0.ff.3.bias
# AMS_lists.1.experts.1.intra_embeddings
# AMS_lists.1.experts.1.W_pos
# AMS_lists.1.experts.1.embeddings_generator.0.0.weight
# AMS_lists.1.experts.1.embeddings_generator.0.0.bias
# AMS_lists.1.experts.1.embeddings_generator.1.0.weight
# AMS_lists.1.experts.1.embeddings_generator.1.0.bias
# AMS_lists.1.experts.1.embeddings_generator.2.0.weight
# AMS_lists.1.experts.1.embeddings_generator.2.0.bias
# AMS_lists.1.experts.1.embeddings_generator.3.0.weight
# AMS_lists.1.experts.1.embeddings_generator.3.0.bias
# AMS_lists.1.experts.1.embeddings_generator.4.0.weight
# AMS_lists.1.experts.1.embeddings_generator.4.0.bias
# AMS_lists.1.experts.1.embeddings_generator.5.0.weight
# AMS_lists.1.experts.1.embeddings_generator.5.0.bias
# AMS_lists.1.experts.1.embeddings_generator.6.0.weight
# AMS_lists.1.experts.1.embeddings_generator.6.0.bias
# AMS_lists.1.experts.1.embeddings_generator.7.0.weight
# AMS_lists.1.experts.1.embeddings_generator.7.0.bias
# AMS_lists.1.experts.1.embeddings_generator.8.0.weight
# AMS_lists.1.experts.1.embeddings_generator.8.0.bias
# AMS_lists.1.experts.1.embeddings_generator.9.0.weight
# AMS_lists.1.experts.1.embeddings_generator.9.0.bias
# AMS_lists.1.experts.1.embeddings_generator.10.0.weight
# AMS_lists.1.experts.1.embeddings_generator.10.0.bias
# AMS_lists.1.experts.1.embeddings_generator.11.0.weight
# AMS_lists.1.experts.1.embeddings_generator.11.0.bias
# AMS_lists.1.experts.1.weights_generator_distinct.memory
# AMS_lists.1.experts.1.weights_generator_distinct.generator.0.weight
# AMS_lists.1.experts.1.weights_generator_distinct.generator.0.bias
# AMS_lists.1.experts.1.weights_generator_distinct.generator.2.weight
# AMS_lists.1.experts.1.weights_generator_distinct.generator.2.bias
# AMS_lists.1.experts.1.weights_generator_distinct.generator.4.weight
# AMS_lists.1.experts.1.weights_generator_distinct.generator.4.bias
# AMS_lists.1.experts.1.weights_generator_distinct.P.0
# AMS_lists.1.experts.1.weights_generator_distinct.P.1
# AMS_lists.1.experts.1.weights_generator_distinct.Q.0
# AMS_lists.1.experts.1.weights_generator_distinct.Q.1
# AMS_lists.1.experts.1.weights_generator_distinct.B.0
# AMS_lists.1.experts.1.weights_generator_distinct.B.1
# AMS_lists.1.experts.1.weights_generator_shared.P.0
# AMS_lists.1.experts.1.weights_generator_shared.P.1
# AMS_lists.1.experts.1.weights_generator_shared.B.0
# AMS_lists.1.experts.1.weights_generator_shared.B.1
# AMS_lists.1.experts.1.intra_Linear.weight
# AMS_lists.1.experts.1.intra_Linear.bias
# AMS_lists.1.experts.1.emb_linear.weight
# AMS_lists.1.experts.1.emb_linear.bias
# AMS_lists.1.experts.1.inter_patch_attention.W_Q.weight
# AMS_lists.1.experts.1.inter_patch_attention.W_Q.bias
# AMS_lists.1.experts.1.inter_patch_attention.W_K.weight
# AMS_lists.1.experts.1.inter_patch_attention.W_K.bias
# AMS_lists.1.experts.1.inter_patch_attention.W_V.weight
# AMS_lists.1.experts.1.inter_patch_attention.W_V.bias
# AMS_lists.1.experts.1.inter_patch_attention.sdp_attn.scale
# AMS_lists.1.experts.1.inter_patch_attention.to_out.0.weight
# AMS_lists.1.experts.1.inter_patch_attention.to_out.0.bias
# AMS_lists.1.experts.1.norm_attn.1.weight
# AMS_lists.1.experts.1.norm_attn.1.bias
# AMS_lists.1.experts.1.norm_attn.1.running_mean
# AMS_lists.1.experts.1.norm_attn.1.running_var
# AMS_lists.1.experts.1.norm_attn.1.num_batches_tracked
# AMS_lists.1.experts.1.norm_ffn.1.weight
# AMS_lists.1.experts.1.norm_ffn.1.bias
# AMS_lists.1.experts.1.norm_ffn.1.running_mean
# AMS_lists.1.experts.1.norm_ffn.1.running_var
# AMS_lists.1.experts.1.norm_ffn.1.num_batches_tracked
# AMS_lists.1.experts.1.ff.0.weight
# AMS_lists.1.experts.1.ff.0.bias
# AMS_lists.1.experts.1.ff.3.weight
# AMS_lists.1.experts.1.ff.3.bias
# AMS_lists.1.experts.2.intra_embeddings
# AMS_lists.1.experts.2.W_pos
# AMS_lists.1.experts.2.embeddings_generator.0.0.weight
# AMS_lists.1.experts.2.embeddings_generator.0.0.bias
# AMS_lists.1.experts.2.embeddings_generator.1.0.weight
# AMS_lists.1.experts.2.embeddings_generator.1.0.bias
# AMS_lists.1.experts.2.embeddings_generator.2.0.weight
# AMS_lists.1.experts.2.embeddings_generator.2.0.bias
# AMS_lists.1.experts.2.embeddings_generator.3.0.weight
# AMS_lists.1.experts.2.embeddings_generator.3.0.bias
# AMS_lists.1.experts.2.embeddings_generator.4.0.weight
# AMS_lists.1.experts.2.embeddings_generator.4.0.bias
# AMS_lists.1.experts.2.embeddings_generator.5.0.weight
# AMS_lists.1.experts.2.embeddings_generator.5.0.bias
# AMS_lists.1.experts.2.embeddings_generator.6.0.weight
# AMS_lists.1.experts.2.embeddings_generator.6.0.bias
# AMS_lists.1.experts.2.embeddings_generator.7.0.weight
# AMS_lists.1.experts.2.embeddings_generator.7.0.bias
# AMS_lists.1.experts.2.embeddings_generator.8.0.weight
# AMS_lists.1.experts.2.embeddings_generator.8.0.bias
# AMS_lists.1.experts.2.embeddings_generator.9.0.weight
# AMS_lists.1.experts.2.embeddings_generator.9.0.bias
# AMS_lists.1.experts.2.embeddings_generator.10.0.weight
# AMS_lists.1.experts.2.embeddings_generator.10.0.bias
# AMS_lists.1.experts.2.embeddings_generator.11.0.weight
# AMS_lists.1.experts.2.embeddings_generator.11.0.bias
# AMS_lists.1.experts.2.embeddings_generator.12.0.weight
# AMS_lists.1.experts.2.embeddings_generator.12.0.bias
# AMS_lists.1.experts.2.embeddings_generator.13.0.weight
# AMS_lists.1.experts.2.embeddings_generator.13.0.bias
# AMS_lists.1.experts.2.embeddings_generator.14.0.weight
# AMS_lists.1.experts.2.embeddings_generator.14.0.bias
# AMS_lists.1.experts.2.embeddings_generator.15.0.weight
# AMS_lists.1.experts.2.embeddings_generator.15.0.bias
# AMS_lists.1.experts.2.weights_generator_distinct.memory
# AMS_lists.1.experts.2.weights_generator_distinct.generator.0.weight
# AMS_lists.1.experts.2.weights_generator_distinct.generator.0.bias
# AMS_lists.1.experts.2.weights_generator_distinct.generator.2.weight
# AMS_lists.1.experts.2.weights_generator_distinct.generator.2.bias
# AMS_lists.1.experts.2.weights_generator_distinct.generator.4.weight
# AMS_lists.1.experts.2.weights_generator_distinct.generator.4.bias
# AMS_lists.1.experts.2.weights_generator_distinct.P.0
# AMS_lists.1.experts.2.weights_generator_distinct.P.1
# AMS_lists.1.experts.2.weights_generator_distinct.Q.0
# AMS_lists.1.experts.2.weights_generator_distinct.Q.1
# AMS_lists.1.experts.2.weights_generator_distinct.B.0
# AMS_lists.1.experts.2.weights_generator_distinct.B.1
# AMS_lists.1.experts.2.weights_generator_shared.P.0
# AMS_lists.1.experts.2.weights_generator_shared.P.1
# AMS_lists.1.experts.2.weights_generator_shared.B.0
# AMS_lists.1.experts.2.weights_generator_shared.B.1
# AMS_lists.1.experts.2.intra_Linear.weight
# AMS_lists.1.experts.2.intra_Linear.bias
# AMS_lists.1.experts.2.emb_linear.weight
# AMS_lists.1.experts.2.emb_linear.bias
# AMS_lists.1.experts.2.inter_patch_attention.W_Q.weight
# AMS_lists.1.experts.2.inter_patch_attention.W_Q.bias
# AMS_lists.1.experts.2.inter_patch_attention.W_K.weight
# AMS_lists.1.experts.2.inter_patch_attention.W_K.bias
# AMS_lists.1.experts.2.inter_patch_attention.W_V.weight
# AMS_lists.1.experts.2.inter_patch_attention.W_V.bias
# AMS_lists.1.experts.2.inter_patch_attention.sdp_attn.scale
# AMS_lists.1.experts.2.inter_patch_attention.to_out.0.weight
# AMS_lists.1.experts.2.inter_patch_attention.to_out.0.bias
# AMS_lists.1.experts.2.norm_attn.1.weight
# AMS_lists.1.experts.2.norm_attn.1.bias
# AMS_lists.1.experts.2.norm_attn.1.running_mean
# AMS_lists.1.experts.2.norm_attn.1.running_var
# AMS_lists.1.experts.2.norm_attn.1.num_batches_tracked
# AMS_lists.1.experts.2.norm_ffn.1.weight
# AMS_lists.1.experts.2.norm_ffn.1.bias
# AMS_lists.1.experts.2.norm_ffn.1.running_mean
# AMS_lists.1.experts.2.norm_ffn.1.running_var
# AMS_lists.1.experts.2.norm_ffn.1.num_batches_tracked
# AMS_lists.1.experts.2.ff.0.weight
# AMS_lists.1.experts.2.ff.0.bias
# AMS_lists.1.experts.2.ff.3.weight
# AMS_lists.1.experts.2.ff.3.bias
# AMS_lists.1.experts.3.intra_embeddings
# AMS_lists.1.experts.3.W_pos
# AMS_lists.1.experts.3.embeddings_generator.0.0.weight
# AMS_lists.1.experts.3.embeddings_generator.0.0.bias
# AMS_lists.1.experts.3.embeddings_generator.1.0.weight
# AMS_lists.1.experts.3.embeddings_generator.1.0.bias
# AMS_lists.1.experts.3.embeddings_generator.2.0.weight
# AMS_lists.1.experts.3.embeddings_generator.2.0.bias
# AMS_lists.1.experts.3.embeddings_generator.3.0.weight
# AMS_lists.1.experts.3.embeddings_generator.3.0.bias
# AMS_lists.1.experts.3.embeddings_generator.4.0.weight
# AMS_lists.1.experts.3.embeddings_generator.4.0.bias
# AMS_lists.1.experts.3.embeddings_generator.5.0.weight
# AMS_lists.1.experts.3.embeddings_generator.5.0.bias
# AMS_lists.1.experts.3.embeddings_generator.6.0.weight
# AMS_lists.1.experts.3.embeddings_generator.6.0.bias
# AMS_lists.1.experts.3.embeddings_generator.7.0.weight
# AMS_lists.1.experts.3.embeddings_generator.7.0.bias
# AMS_lists.1.experts.3.embeddings_generator.8.0.weight
# AMS_lists.1.experts.3.embeddings_generator.8.0.bias
# AMS_lists.1.experts.3.embeddings_generator.9.0.weight
# AMS_lists.1.experts.3.embeddings_generator.9.0.bias
# AMS_lists.1.experts.3.embeddings_generator.10.0.weight
# AMS_lists.1.experts.3.embeddings_generator.10.0.bias
# AMS_lists.1.experts.3.embeddings_generator.11.0.weight
# AMS_lists.1.experts.3.embeddings_generator.11.0.bias
# AMS_lists.1.experts.3.embeddings_generator.12.0.weight
# AMS_lists.1.experts.3.embeddings_generator.12.0.bias
# AMS_lists.1.experts.3.embeddings_generator.13.0.weight
# AMS_lists.1.experts.3.embeddings_generator.13.0.bias
# AMS_lists.1.experts.3.embeddings_generator.14.0.weight
# AMS_lists.1.experts.3.embeddings_generator.14.0.bias
# AMS_lists.1.experts.3.embeddings_generator.15.0.weight
# AMS_lists.1.experts.3.embeddings_generator.15.0.bias
# AMS_lists.1.experts.3.embeddings_generator.16.0.weight
# AMS_lists.1.experts.3.embeddings_generator.16.0.bias
# AMS_lists.1.experts.3.embeddings_generator.17.0.weight
# AMS_lists.1.experts.3.embeddings_generator.17.0.bias
# AMS_lists.1.experts.3.embeddings_generator.18.0.weight
# AMS_lists.1.experts.3.embeddings_generator.18.0.bias
# AMS_lists.1.experts.3.embeddings_generator.19.0.weight
# AMS_lists.1.experts.3.embeddings_generator.19.0.bias
# AMS_lists.1.experts.3.embeddings_generator.20.0.weight
# AMS_lists.1.experts.3.embeddings_generator.20.0.bias
# AMS_lists.1.experts.3.embeddings_generator.21.0.weight
# AMS_lists.1.experts.3.embeddings_generator.21.0.bias
# AMS_lists.1.experts.3.embeddings_generator.22.0.weight
# AMS_lists.1.experts.3.embeddings_generator.22.0.bias
# AMS_lists.1.experts.3.embeddings_generator.23.0.weight
# AMS_lists.1.experts.3.embeddings_generator.23.0.bias
# AMS_lists.1.experts.3.weights_generator_distinct.memory
# AMS_lists.1.experts.3.weights_generator_distinct.generator.0.weight
# AMS_lists.1.experts.3.weights_generator_distinct.generator.0.bias
# AMS_lists.1.experts.3.weights_generator_distinct.generator.2.weight
# AMS_lists.1.experts.3.weights_generator_distinct.generator.2.bias
# AMS_lists.1.experts.3.weights_generator_distinct.generator.4.weight
# AMS_lists.1.experts.3.weights_generator_distinct.generator.4.bias
# AMS_lists.1.experts.3.weights_generator_distinct.P.0
# AMS_lists.1.experts.3.weights_generator_distinct.P.1
# AMS_lists.1.experts.3.weights_generator_distinct.Q.0
# AMS_lists.1.experts.3.weights_generator_distinct.Q.1
# AMS_lists.1.experts.3.weights_generator_distinct.B.0
# AMS_lists.1.experts.3.weights_generator_distinct.B.1
# AMS_lists.1.experts.3.weights_generator_shared.P.0
# AMS_lists.1.experts.3.weights_generator_shared.P.1
# AMS_lists.1.experts.3.weights_generator_shared.B.0
# AMS_lists.1.experts.3.weights_generator_shared.B.1
# AMS_lists.1.experts.3.intra_Linear.weight
# AMS_lists.1.experts.3.intra_Linear.bias
# AMS_lists.1.experts.3.emb_linear.weight
# AMS_lists.1.experts.3.emb_linear.bias
# AMS_lists.1.experts.3.inter_patch_attention.W_Q.weight
# AMS_lists.1.experts.3.inter_patch_attention.W_Q.bias
# AMS_lists.1.experts.3.inter_patch_attention.W_K.weight
# AMS_lists.1.experts.3.inter_patch_attention.W_K.bias
# AMS_lists.1.experts.3.inter_patch_attention.W_V.weight
# AMS_lists.1.experts.3.inter_patch_attention.W_V.bias
# AMS_lists.1.experts.3.inter_patch_attention.sdp_attn.scale
# AMS_lists.1.experts.3.inter_patch_attention.to_out.0.weight
# AMS_lists.1.experts.3.inter_patch_attention.to_out.0.bias
# AMS_lists.1.experts.3.norm_attn.1.weight
# AMS_lists.1.experts.3.norm_attn.1.bias
# AMS_lists.1.experts.3.norm_attn.1.running_mean
# AMS_lists.1.experts.3.norm_attn.1.running_var
# AMS_lists.1.experts.3.norm_attn.1.num_batches_tracked
# AMS_lists.1.experts.3.norm_ffn.1.weight
# AMS_lists.1.experts.3.norm_ffn.1.bias
# AMS_lists.1.experts.3.norm_ffn.1.running_mean
# AMS_lists.1.experts.3.norm_ffn.1.running_var
# AMS_lists.1.experts.3.norm_ffn.1.num_batches_tracked
# AMS_lists.1.experts.3.ff.0.weight
# AMS_lists.1.experts.3.ff.0.bias
# AMS_lists.1.experts.3.ff.3.weight
# AMS_lists.1.experts.3.ff.3.bias
# AMS_lists.1.w_noise.weight
# AMS_lists.1.w_noise.bias
# AMS_lists.1.w_noise_norm.weight
# AMS_lists.1.w_noise_norm.bias
# AMS_lists.1.w_gate.weight
# AMS_lists.1.w_gate.bias
# AMS_lists.1.w_gate_norm.weight
# AMS_lists.1.w_gate_norm.bias
# AMS_lists.1.end_MLP.fc.weight
# AMS_lists.1.end_MLP.fc.bias
# AMS_lists.2.mean
# AMS_lists.2.std
# AMS_lists.2.start_linear.weight
# AMS_lists.2.start_linear.bias
# AMS_lists.2.trend_model.layer.weight
# AMS_lists.2.trend_model.layer.bias
# AMS_lists.2.experts.0.intra_embeddings
# AMS_lists.2.experts.0.W_pos
# AMS_lists.2.experts.0.embeddings_generator.0.0.weight
# AMS_lists.2.experts.0.embeddings_generator.0.0.bias
# AMS_lists.2.experts.0.embeddings_generator.1.0.weight
# AMS_lists.2.experts.0.embeddings_generator.1.0.bias
# AMS_lists.2.experts.0.embeddings_generator.2.0.weight
# AMS_lists.2.experts.0.embeddings_generator.2.0.bias
# AMS_lists.2.experts.0.embeddings_generator.3.0.weight
# AMS_lists.2.experts.0.embeddings_generator.3.0.bias
# AMS_lists.2.experts.0.embeddings_generator.4.0.weight
# AMS_lists.2.experts.0.embeddings_generator.4.0.bias
# AMS_lists.2.experts.0.embeddings_generator.5.0.weight
# AMS_lists.2.experts.0.embeddings_generator.5.0.bias
# AMS_lists.2.experts.0.embeddings_generator.6.0.weight
# AMS_lists.2.experts.0.embeddings_generator.6.0.bias
# AMS_lists.2.experts.0.embeddings_generator.7.0.weight
# AMS_lists.2.experts.0.embeddings_generator.7.0.bias
# AMS_lists.2.experts.0.embeddings_generator.8.0.weight
# AMS_lists.2.experts.0.embeddings_generator.8.0.bias
# AMS_lists.2.experts.0.embeddings_generator.9.0.weight
# AMS_lists.2.experts.0.embeddings_generator.9.0.bias
# AMS_lists.2.experts.0.embeddings_generator.10.0.weight
# AMS_lists.2.experts.0.embeddings_generator.10.0.bias
# AMS_lists.2.experts.0.embeddings_generator.11.0.weight
# AMS_lists.2.experts.0.embeddings_generator.11.0.bias
# AMS_lists.2.experts.0.weights_generator_distinct.memory
# AMS_lists.2.experts.0.weights_generator_distinct.generator.0.weight
# AMS_lists.2.experts.0.weights_generator_distinct.generator.0.bias
# AMS_lists.2.experts.0.weights_generator_distinct.generator.2.weight
# AMS_lists.2.experts.0.weights_generator_distinct.generator.2.bias
# AMS_lists.2.experts.0.weights_generator_distinct.generator.4.weight
# AMS_lists.2.experts.0.weights_generator_distinct.generator.4.bias
# AMS_lists.2.experts.0.weights_generator_distinct.P.0
# AMS_lists.2.experts.0.weights_generator_distinct.P.1
# AMS_lists.2.experts.0.weights_generator_distinct.Q.0
# AMS_lists.2.experts.0.weights_generator_distinct.Q.1
# AMS_lists.2.experts.0.weights_generator_distinct.B.0
# AMS_lists.2.experts.0.weights_generator_distinct.B.1
# AMS_lists.2.experts.0.weights_generator_shared.P.0
# AMS_lists.2.experts.0.weights_generator_shared.P.1
# AMS_lists.2.experts.0.weights_generator_shared.B.0
# AMS_lists.2.experts.0.weights_generator_shared.B.1
# AMS_lists.2.experts.0.intra_Linear.weight
# AMS_lists.2.experts.0.intra_Linear.bias
# AMS_lists.2.experts.0.emb_linear.weight
# AMS_lists.2.experts.0.emb_linear.bias
# AMS_lists.2.experts.0.inter_patch_attention.W_Q.weight
# AMS_lists.2.experts.0.inter_patch_attention.W_Q.bias
# AMS_lists.2.experts.0.inter_patch_attention.W_K.weight
# AMS_lists.2.experts.0.inter_patch_attention.W_K.bias
# AMS_lists.2.experts.0.inter_patch_attention.W_V.weight
# AMS_lists.2.experts.0.inter_patch_attention.W_V.bias
# AMS_lists.2.experts.0.inter_patch_attention.sdp_attn.scale
# AMS_lists.2.experts.0.inter_patch_attention.to_out.0.weight
# AMS_lists.2.experts.0.inter_patch_attention.to_out.0.bias
# AMS_lists.2.experts.0.norm_attn.1.weight
# AMS_lists.2.experts.0.norm_attn.1.bias
# AMS_lists.2.experts.0.norm_attn.1.running_mean
# AMS_lists.2.experts.0.norm_attn.1.running_var
# AMS_lists.2.experts.0.norm_attn.1.num_batches_tracked
# AMS_lists.2.experts.0.norm_ffn.1.weight
# AMS_lists.2.experts.0.norm_ffn.1.bias
# AMS_lists.2.experts.0.norm_ffn.1.running_mean
# AMS_lists.2.experts.0.norm_ffn.1.running_var
# AMS_lists.2.experts.0.norm_ffn.1.num_batches_tracked
# AMS_lists.2.experts.0.ff.0.weight
# AMS_lists.2.experts.0.ff.0.bias
# AMS_lists.2.experts.0.ff.3.weight
# AMS_lists.2.experts.0.ff.3.bias
# AMS_lists.2.experts.1.intra_embeddings
# AMS_lists.2.experts.1.W_pos
# AMS_lists.2.experts.1.embeddings_generator.0.0.weight
# AMS_lists.2.experts.1.embeddings_generator.0.0.bias
# AMS_lists.2.experts.1.embeddings_generator.1.0.weight
# AMS_lists.2.experts.1.embeddings_generator.1.0.bias
# AMS_lists.2.experts.1.embeddings_generator.2.0.weight
# AMS_lists.2.experts.1.embeddings_generator.2.0.bias
# AMS_lists.2.experts.1.embeddings_generator.3.0.weight
# AMS_lists.2.experts.1.embeddings_generator.3.0.bias
# AMS_lists.2.experts.1.embeddings_generator.4.0.weight
# AMS_lists.2.experts.1.embeddings_generator.4.0.bias
# AMS_lists.2.experts.1.embeddings_generator.5.0.weight
# AMS_lists.2.experts.1.embeddings_generator.5.0.bias
# AMS_lists.2.experts.1.embeddings_generator.6.0.weight
# AMS_lists.2.experts.1.embeddings_generator.6.0.bias
# AMS_lists.2.experts.1.embeddings_generator.7.0.weight
# AMS_lists.2.experts.1.embeddings_generator.7.0.bias
# AMS_lists.2.experts.1.embeddings_generator.8.0.weight
# AMS_lists.2.experts.1.embeddings_generator.8.0.bias
# AMS_lists.2.experts.1.embeddings_generator.9.0.weight
# AMS_lists.2.experts.1.embeddings_generator.9.0.bias
# AMS_lists.2.experts.1.embeddings_generator.10.0.weight
# AMS_lists.2.experts.1.embeddings_generator.10.0.bias
# AMS_lists.2.experts.1.embeddings_generator.11.0.weight
# AMS_lists.2.experts.1.embeddings_generator.11.0.bias
# AMS_lists.2.experts.1.embeddings_generator.12.0.weight
# AMS_lists.2.experts.1.embeddings_generator.12.0.bias
# AMS_lists.2.experts.1.embeddings_generator.13.0.weight
# AMS_lists.2.experts.1.embeddings_generator.13.0.bias
# AMS_lists.2.experts.1.embeddings_generator.14.0.weight
# AMS_lists.2.experts.1.embeddings_generator.14.0.bias
# AMS_lists.2.experts.1.embeddings_generator.15.0.weight
# AMS_lists.2.experts.1.embeddings_generator.15.0.bias
# AMS_lists.2.experts.1.weights_generator_distinct.memory
# AMS_lists.2.experts.1.weights_generator_distinct.generator.0.weight
# AMS_lists.2.experts.1.weights_generator_distinct.generator.0.bias
# AMS_lists.2.experts.1.weights_generator_distinct.generator.2.weight
# AMS_lists.2.experts.1.weights_generator_distinct.generator.2.bias
# AMS_lists.2.experts.1.weights_generator_distinct.generator.4.weight
# AMS_lists.2.experts.1.weights_generator_distinct.generator.4.bias
# AMS_lists.2.experts.1.weights_generator_distinct.P.0
# AMS_lists.2.experts.1.weights_generator_distinct.P.1
# AMS_lists.2.experts.1.weights_generator_distinct.Q.0
# AMS_lists.2.experts.1.weights_generator_distinct.Q.1
# AMS_lists.2.experts.1.weights_generator_distinct.B.0
# AMS_lists.2.experts.1.weights_generator_distinct.B.1
# AMS_lists.2.experts.1.weights_generator_shared.P.0
# AMS_lists.2.experts.1.weights_generator_shared.P.1
# AMS_lists.2.experts.1.weights_generator_shared.B.0
# AMS_lists.2.experts.1.weights_generator_shared.B.1
# AMS_lists.2.experts.1.intra_Linear.weight
# AMS_lists.2.experts.1.intra_Linear.bias
# AMS_lists.2.experts.1.emb_linear.weight
# AMS_lists.2.experts.1.emb_linear.bias
# AMS_lists.2.experts.1.inter_patch_attention.W_Q.weight
# AMS_lists.2.experts.1.inter_patch_attention.W_Q.bias
# AMS_lists.2.experts.1.inter_patch_attention.W_K.weight
# AMS_lists.2.experts.1.inter_patch_attention.W_K.bias
# AMS_lists.2.experts.1.inter_patch_attention.W_V.weight
# AMS_lists.2.experts.1.inter_patch_attention.W_V.bias
# AMS_lists.2.experts.1.inter_patch_attention.sdp_attn.scale
# AMS_lists.2.experts.1.inter_patch_attention.to_out.0.weight
# AMS_lists.2.experts.1.inter_patch_attention.to_out.0.bias
# AMS_lists.2.experts.1.norm_attn.1.weight
# AMS_lists.2.experts.1.norm_attn.1.bias
# AMS_lists.2.experts.1.norm_attn.1.running_mean
# AMS_lists.2.experts.1.norm_attn.1.running_var
# AMS_lists.2.experts.1.norm_attn.1.num_batches_tracked
# AMS_lists.2.experts.1.norm_ffn.1.weight
# AMS_lists.2.experts.1.norm_ffn.1.bias
# AMS_lists.2.experts.1.norm_ffn.1.running_mean
# AMS_lists.2.experts.1.norm_ffn.1.running_var
# AMS_lists.2.experts.1.norm_ffn.1.num_batches_tracked
# AMS_lists.2.experts.1.ff.0.weight
# AMS_lists.2.experts.1.ff.0.bias
# AMS_lists.2.experts.1.ff.3.weight
# AMS_lists.2.experts.1.ff.3.bias
# AMS_lists.2.experts.2.intra_embeddings
# AMS_lists.2.experts.2.W_pos
# AMS_lists.2.experts.2.embeddings_generator.0.0.weight
# AMS_lists.2.experts.2.embeddings_generator.0.0.bias
# AMS_lists.2.experts.2.embeddings_generator.1.0.weight
# AMS_lists.2.experts.2.embeddings_generator.1.0.bias
# AMS_lists.2.experts.2.embeddings_generator.2.0.weight
# AMS_lists.2.experts.2.embeddings_generator.2.0.bias
# AMS_lists.2.experts.2.embeddings_generator.3.0.weight
# AMS_lists.2.experts.2.embeddings_generator.3.0.bias
# AMS_lists.2.experts.2.embeddings_generator.4.0.weight
# AMS_lists.2.experts.2.embeddings_generator.4.0.bias
# AMS_lists.2.experts.2.embeddings_generator.5.0.weight
# AMS_lists.2.experts.2.embeddings_generator.5.0.bias
# AMS_lists.2.experts.2.embeddings_generator.6.0.weight
# AMS_lists.2.experts.2.embeddings_generator.6.0.bias
# AMS_lists.2.experts.2.embeddings_generator.7.0.weight
# AMS_lists.2.experts.2.embeddings_generator.7.0.bias
# AMS_lists.2.experts.2.embeddings_generator.8.0.weight
# AMS_lists.2.experts.2.embeddings_generator.8.0.bias
# AMS_lists.2.experts.2.embeddings_generator.9.0.weight
# AMS_lists.2.experts.2.embeddings_generator.9.0.bias
# AMS_lists.2.experts.2.embeddings_generator.10.0.weight
# AMS_lists.2.experts.2.embeddings_generator.10.0.bias
# AMS_lists.2.experts.2.embeddings_generator.11.0.weight
# AMS_lists.2.experts.2.embeddings_generator.11.0.bias
# AMS_lists.2.experts.2.embeddings_generator.12.0.weight
# AMS_lists.2.experts.2.embeddings_generator.12.0.bias
# AMS_lists.2.experts.2.embeddings_generator.13.0.weight
# AMS_lists.2.experts.2.embeddings_generator.13.0.bias
# AMS_lists.2.experts.2.embeddings_generator.14.0.weight
# AMS_lists.2.experts.2.embeddings_generator.14.0.bias
# AMS_lists.2.experts.2.embeddings_generator.15.0.weight
# AMS_lists.2.experts.2.embeddings_generator.15.0.bias
# AMS_lists.2.experts.2.embeddings_generator.16.0.weight
# AMS_lists.2.experts.2.embeddings_generator.16.0.bias
# AMS_lists.2.experts.2.embeddings_generator.17.0.weight
# AMS_lists.2.experts.2.embeddings_generator.17.0.bias
# AMS_lists.2.experts.2.embeddings_generator.18.0.weight
# AMS_lists.2.experts.2.embeddings_generator.18.0.bias
# AMS_lists.2.experts.2.embeddings_generator.19.0.weight
# AMS_lists.2.experts.2.embeddings_generator.19.0.bias
# AMS_lists.2.experts.2.embeddings_generator.20.0.weight
# AMS_lists.2.experts.2.embeddings_generator.20.0.bias
# AMS_lists.2.experts.2.embeddings_generator.21.0.weight
# AMS_lists.2.experts.2.embeddings_generator.21.0.bias
# AMS_lists.2.experts.2.embeddings_generator.22.0.weight
# AMS_lists.2.experts.2.embeddings_generator.22.0.bias
# AMS_lists.2.experts.2.embeddings_generator.23.0.weight
# AMS_lists.2.experts.2.embeddings_generator.23.0.bias
# AMS_lists.2.experts.2.weights_generator_distinct.memory
# AMS_lists.2.experts.2.weights_generator_distinct.generator.0.weight
# AMS_lists.2.experts.2.weights_generator_distinct.generator.0.bias
# AMS_lists.2.experts.2.weights_generator_distinct.generator.2.weight
# AMS_lists.2.experts.2.weights_generator_distinct.generator.2.bias
# AMS_lists.2.experts.2.weights_generator_distinct.generator.4.weight
# AMS_lists.2.experts.2.weights_generator_distinct.generator.4.bias
# AMS_lists.2.experts.2.weights_generator_distinct.P.0
# AMS_lists.2.experts.2.weights_generator_distinct.P.1
# AMS_lists.2.experts.2.weights_generator_distinct.Q.0
# AMS_lists.2.experts.2.weights_generator_distinct.Q.1
# AMS_lists.2.experts.2.weights_generator_distinct.B.0
# AMS_lists.2.experts.2.weights_generator_distinct.B.1
# AMS_lists.2.experts.2.weights_generator_shared.P.0
# AMS_lists.2.experts.2.weights_generator_shared.P.1
# AMS_lists.2.experts.2.weights_generator_shared.B.0
# AMS_lists.2.experts.2.weights_generator_shared.B.1
# AMS_lists.2.experts.2.intra_Linear.weight
# AMS_lists.2.experts.2.intra_Linear.bias
# AMS_lists.2.experts.2.emb_linear.weight
# AMS_lists.2.experts.2.emb_linear.bias
# AMS_lists.2.experts.2.inter_patch_attention.W_Q.weight
# AMS_lists.2.experts.2.inter_patch_attention.W_Q.bias
# AMS_lists.2.experts.2.inter_patch_attention.W_K.weight
# AMS_lists.2.experts.2.inter_patch_attention.W_K.bias
# AMS_lists.2.experts.2.inter_patch_attention.W_V.weight
# AMS_lists.2.experts.2.inter_patch_attention.W_V.bias
# AMS_lists.2.experts.2.inter_patch_attention.sdp_attn.scale
# AMS_lists.2.experts.2.inter_patch_attention.to_out.0.weight
# AMS_lists.2.experts.2.inter_patch_attention.to_out.0.bias
# AMS_lists.2.experts.2.norm_attn.1.weight
# AMS_lists.2.experts.2.norm_attn.1.bias
# AMS_lists.2.experts.2.norm_attn.1.running_mean
# AMS_lists.2.experts.2.norm_attn.1.running_var
# AMS_lists.2.experts.2.norm_attn.1.num_batches_tracked
# AMS_lists.2.experts.2.norm_ffn.1.weight
# AMS_lists.2.experts.2.norm_ffn.1.bias
# AMS_lists.2.experts.2.norm_ffn.1.running_mean
# AMS_lists.2.experts.2.norm_ffn.1.running_var
# AMS_lists.2.experts.2.norm_ffn.1.num_batches_tracked
# AMS_lists.2.experts.2.ff.0.weight
# AMS_lists.2.experts.2.ff.0.bias
# AMS_lists.2.experts.2.ff.3.weight
# AMS_lists.2.experts.2.ff.3.bias
# AMS_lists.2.experts.3.intra_embeddings
# AMS_lists.2.experts.3.W_pos
# AMS_lists.2.experts.3.embeddings_generator.0.0.weight
# AMS_lists.2.experts.3.embeddings_generator.0.0.bias
# AMS_lists.2.experts.3.embeddings_generator.1.0.weight
# AMS_lists.2.experts.3.embeddings_generator.1.0.bias
# AMS_lists.2.experts.3.embeddings_generator.2.0.weight
# AMS_lists.2.experts.3.embeddings_generator.2.0.bias
# AMS_lists.2.experts.3.embeddings_generator.3.0.weight
# AMS_lists.2.experts.3.embeddings_generator.3.0.bias
# AMS_lists.2.experts.3.embeddings_generator.4.0.weight
# AMS_lists.2.experts.3.embeddings_generator.4.0.bias
# AMS_lists.2.experts.3.embeddings_generator.5.0.weight
# AMS_lists.2.experts.3.embeddings_generator.5.0.bias
# AMS_lists.2.experts.3.embeddings_generator.6.0.weight
# AMS_lists.2.experts.3.embeddings_generator.6.0.bias
# AMS_lists.2.experts.3.embeddings_generator.7.0.weight
# AMS_lists.2.experts.3.embeddings_generator.7.0.bias
# AMS_lists.2.experts.3.embeddings_generator.8.0.weight
# AMS_lists.2.experts.3.embeddings_generator.8.0.bias
# AMS_lists.2.experts.3.embeddings_generator.9.0.weight
# AMS_lists.2.experts.3.embeddings_generator.9.0.bias
# AMS_lists.2.experts.3.embeddings_generator.10.0.weight
# AMS_lists.2.experts.3.embeddings_generator.10.0.bias
# AMS_lists.2.experts.3.embeddings_generator.11.0.weight
# AMS_lists.2.experts.3.embeddings_generator.11.0.bias
# AMS_lists.2.experts.3.embeddings_generator.12.0.weight
# AMS_lists.2.experts.3.embeddings_generator.12.0.bias
# AMS_lists.2.experts.3.embeddings_generator.13.0.weight
# AMS_lists.2.experts.3.embeddings_generator.13.0.bias
# AMS_lists.2.experts.3.embeddings_generator.14.0.weight
# AMS_lists.2.experts.3.embeddings_generator.14.0.bias
# AMS_lists.2.experts.3.embeddings_generator.15.0.weight
# AMS_lists.2.experts.3.embeddings_generator.15.0.bias
# AMS_lists.2.experts.3.embeddings_generator.16.0.weight
# AMS_lists.2.experts.3.embeddings_generator.16.0.bias
# AMS_lists.2.experts.3.embeddings_generator.17.0.weight
# AMS_lists.2.experts.3.embeddings_generator.17.0.bias
# AMS_lists.2.experts.3.embeddings_generator.18.0.weight
# AMS_lists.2.experts.3.embeddings_generator.18.0.bias
# AMS_lists.2.experts.3.embeddings_generator.19.0.weight
# AMS_lists.2.experts.3.embeddings_generator.19.0.bias
# AMS_lists.2.experts.3.embeddings_generator.20.0.weight
# AMS_lists.2.experts.3.embeddings_generator.20.0.bias
# AMS_lists.2.experts.3.embeddings_generator.21.0.weight
# AMS_lists.2.experts.3.embeddings_generator.21.0.bias
# AMS_lists.2.experts.3.embeddings_generator.22.0.weight
# AMS_lists.2.experts.3.embeddings_generator.22.0.bias
# AMS_lists.2.experts.3.embeddings_generator.23.0.weight
# AMS_lists.2.experts.3.embeddings_generator.23.0.bias
# AMS_lists.2.experts.3.embeddings_generator.24.0.weight
# AMS_lists.2.experts.3.embeddings_generator.24.0.bias
# AMS_lists.2.experts.3.embeddings_generator.25.0.weight
# AMS_lists.2.experts.3.embeddings_generator.25.0.bias
# AMS_lists.2.experts.3.embeddings_generator.26.0.weight
# AMS_lists.2.experts.3.embeddings_generator.26.0.bias
# AMS_lists.2.experts.3.embeddings_generator.27.0.weight
# AMS_lists.2.experts.3.embeddings_generator.27.0.bias
# AMS_lists.2.experts.3.embeddings_generator.28.0.weight
# AMS_lists.2.experts.3.embeddings_generator.28.0.bias
# AMS_lists.2.experts.3.embeddings_generator.29.0.weight
# AMS_lists.2.experts.3.embeddings_generator.29.0.bias
# AMS_lists.2.experts.3.embeddings_generator.30.0.weight
# AMS_lists.2.experts.3.embeddings_generator.30.0.bias
# AMS_lists.2.experts.3.embeddings_generator.31.0.weight
# AMS_lists.2.experts.3.embeddings_generator.31.0.bias
# AMS_lists.2.experts.3.embeddings_generator.32.0.weight
# AMS_lists.2.experts.3.embeddings_generator.32.0.bias
# AMS_lists.2.experts.3.embeddings_generator.33.0.weight
# AMS_lists.2.experts.3.embeddings_generator.33.0.bias
# AMS_lists.2.experts.3.embeddings_generator.34.0.weight
# AMS_lists.2.experts.3.embeddings_generator.34.0.bias
# AMS_lists.2.experts.3.embeddings_generator.35.0.weight
# AMS_lists.2.experts.3.embeddings_generator.35.0.bias
# AMS_lists.2.experts.3.embeddings_generator.36.0.weight
# AMS_lists.2.experts.3.embeddings_generator.36.0.bias
# AMS_lists.2.experts.3.embeddings_generator.37.0.weight
# AMS_lists.2.experts.3.embeddings_generator.37.0.bias
# AMS_lists.2.experts.3.embeddings_generator.38.0.weight
# AMS_lists.2.experts.3.embeddings_generator.38.0.bias
# AMS_lists.2.experts.3.embeddings_generator.39.0.weight
# AMS_lists.2.experts.3.embeddings_generator.39.0.bias
# AMS_lists.2.experts.3.embeddings_generator.40.0.weight
# AMS_lists.2.experts.3.embeddings_generator.40.0.bias
# AMS_lists.2.experts.3.embeddings_generator.41.0.weight
# AMS_lists.2.experts.3.embeddings_generator.41.0.bias
# AMS_lists.2.experts.3.embeddings_generator.42.0.weight
# AMS_lists.2.experts.3.embeddings_generator.42.0.bias
# AMS_lists.2.experts.3.embeddings_generator.43.0.weight
# AMS_lists.2.experts.3.embeddings_generator.43.0.bias
# AMS_lists.2.experts.3.embeddings_generator.44.0.weight
# AMS_lists.2.experts.3.embeddings_generator.44.0.bias
# AMS_lists.2.experts.3.embeddings_generator.45.0.weight
# AMS_lists.2.experts.3.embeddings_generator.45.0.bias
# AMS_lists.2.experts.3.embeddings_generator.46.0.weight
# AMS_lists.2.experts.3.embeddings_generator.46.0.bias
# AMS_lists.2.experts.3.embeddings_generator.47.0.weight
# AMS_lists.2.experts.3.embeddings_generator.47.0.bias
# AMS_lists.2.experts.3.weights_generator_distinct.memory
# AMS_lists.2.experts.3.weights_generator_distinct.generator.0.weight
# AMS_lists.2.experts.3.weights_generator_distinct.generator.0.bias
# AMS_lists.2.experts.3.weights_generator_distinct.generator.2.weight
# AMS_lists.2.experts.3.weights_generator_distinct.generator.2.bias
# AMS_lists.2.experts.3.weights_generator_distinct.generator.4.weight
# AMS_lists.2.experts.3.weights_generator_distinct.generator.4.bias
# AMS_lists.2.experts.3.weights_generator_distinct.P.0
# AMS_lists.2.experts.3.weights_generator_distinct.P.1
# AMS_lists.2.experts.3.weights_generator_distinct.Q.0
# AMS_lists.2.experts.3.weights_generator_distinct.Q.1
# AMS_lists.2.experts.3.weights_generator_distinct.B.0
# AMS_lists.2.experts.3.weights_generator_distinct.B.1
# AMS_lists.2.experts.3.weights_generator_shared.P.0
# AMS_lists.2.experts.3.weights_generator_shared.P.1
# AMS_lists.2.experts.3.weights_generator_shared.B.0
# AMS_lists.2.experts.3.weights_generator_shared.B.1
# AMS_lists.2.experts.3.intra_Linear.weight
# AMS_lists.2.experts.3.intra_Linear.bias
# AMS_lists.2.experts.3.emb_linear.weight
# AMS_lists.2.experts.3.emb_linear.bias
# AMS_lists.2.experts.3.inter_patch_attention.W_Q.weight
# AMS_lists.2.experts.3.inter_patch_attention.W_Q.bias
# AMS_lists.2.experts.3.inter_patch_attention.W_K.weight
# AMS_lists.2.experts.3.inter_patch_attention.W_K.bias
# AMS_lists.2.experts.3.inter_patch_attention.W_V.weight
# AMS_lists.2.experts.3.inter_patch_attention.W_V.bias
# AMS_lists.2.experts.3.inter_patch_attention.sdp_attn.scale
# AMS_lists.2.experts.3.inter_patch_attention.to_out.0.weight
# AMS_lists.2.experts.3.inter_patch_attention.to_out.0.bias
# AMS_lists.2.experts.3.norm_attn.1.weight
# AMS_lists.2.experts.3.norm_attn.1.bias
# AMS_lists.2.experts.3.norm_attn.1.running_mean
# AMS_lists.2.experts.3.norm_attn.1.running_var
# AMS_lists.2.experts.3.norm_attn.1.num_batches_tracked
# AMS_lists.2.experts.3.norm_ffn.1.weight
# AMS_lists.2.experts.3.norm_ffn.1.bias
# AMS_lists.2.experts.3.norm_ffn.1.running_mean
# AMS_lists.2.experts.3.norm_ffn.1.running_var
# AMS_lists.2.experts.3.norm_ffn.1.num_batches_tracked
# AMS_lists.2.experts.3.ff.0.weight
# AMS_lists.2.experts.3.ff.0.bias
# AMS_lists.2.experts.3.ff.3.weight
# AMS_lists.2.experts.3.ff.3.bias
# AMS_lists.2.w_noise.weight
# AMS_lists.2.w_noise.bias
# AMS_lists.2.w_noise_norm.weight
# AMS_lists.2.w_noise_norm.bias
# AMS_lists.2.w_gate.weight
# AMS_lists.2.w_gate.bias
# AMS_lists.2.w_gate_norm.weight
# AMS_lists.2.w_gate_norm.bias
# AMS_lists.2.end_MLP.fc.weight
# AMS_lists.2.end_MLP.fc.bias
# projections.0.weight
# projections.0.bias
#
# Extracting trend_model parameters:
# Linear Layer Weight:
# tensor([[ 0.2814],
#         [-0.7728],
#         [ 0.8108]], device='cuda:0')
# Linear Layer Bias:
# tensor([0.0602, 0.9528, 0.1773], device='cuda:0')

# %%
# 提取以 `trend_model` 开头的参数  
trend_model_state_dict = {k.replace("AMS_lists.2.trend_model.", ""): v for k, v in state_dict.items() if "AMS_lists.2.trend_model." in k} 
print(trend_model_state_dict)
# Out:
# {'layer.weight': tensor([[ 0.2814],
#         [-0.7728],
#         [ 0.8108]], device='cuda:0'), 'layer.bias': tensor([0.0602, 0.9528, 0.1773], device='cuda:0')}

# %%
trend_model = series_decomp_multi(kernel_size=[4, 8, 12])
trend_model.load_state_dict(trend_model_state_dict)
trend_model.eval()

def seasonality_and_trend_decompose(x, trend_model=trend_model):
    from utils.Other import FourierLayer
    seasonality_model = FourierLayer(pred_len=0, k=3)
    trend_model = series_decomp_multi(kernel_size=[4, 8, 12])
    # x = x[:, :, :, 0]
    _, trend = trend_model(x)
    seasonality, _ = seasonality_model(x)
    return x + seasonality + trend

# %%
x = torch.randn(128,96,18)
new_x = seasonality_and_trend_decompose(x)
print("new_x shape:", new_x.shape)
x = x.numpy()
new_x = new_x.detach().cpu().numpy()
# Out:
# new_x shape: torch.Size([128, 96, 18])

# %%
print(x[0,:,0].shape)
print(new_x[0,:,0].shape)
# Out:
# (96,)
# (96,)

# %%
# 可视化x和new_x的第一个样本的第一个维度
# plt.figure(figsize=(10, 6))
plt.plot(x[1,:,1], label='Original')
plt.plot(new_x[1,:,1], label='Decomposed')
plt.legend()
plt.show()

# %%
test_data = np.load('label_results/dataset_re_bs128_sl96_dm16_df16_ln3_k2_embtimeF_ar20.0_lr1e-05_pt20_te50_bn1_0/test_data.npy')
print(test_data.shape)
# Out:
# (4480, 96, 18)

# %%
x = test_data[511:511+128, :, :]
x = torch.from_numpy(x).float()
new_x = seasonality_and_trend_decompose(x)
print("new_x shape:", new_x.shape)
x = x.numpy()
new_x = new_x.detach().cpu().numpy()
# print(x[0,:,0].shape)
# Out:
# new_x shape: torch.Size([128, 96, 18])

# %%
plt.plot(x[45,:,1], label='Original')
plt.plot(new_x[45,:,1], label='Decomposed')
plt.legend()
plt.show()

# %%
# 将test_data按照第0维进行划分，每128个样本一组输入到seasonality_and_trend_decompose函数中，并将结果保存到新的数组中
new_test_data = []
for i in range(0, test_data.shape[0], 128):
    x = test_data[i:i+128, :, :]
    x = torch.from_numpy(x).float()
    new_x = seasonality_and_trend_decompose(x)
    new_test_data.append(new_x.detach().cpu().numpy())
new_test_data = np.concatenate(new_test_data, axis=0)
print(new_test_data.shape)
# 保存new_test_data到文件中
np.save('label_results/dataset_re_bs128_sl96_dm16_df16_ln3_k2_embtimeF_ar20.0_lr1e-05_pt20_te50_bn1_0/test_data_decomposed.npy', new_test_data)
# 将new_test_data堆叠
new_test_data = np.concatenate(new_test_data, axis=0)
# 保存为csv文件
np.savetxt('label_results/dataset_re_bs128_sl96_dm16_df16_ln3_k2_embtimeF_ar20.0_lr1e-05_pt20_te50_bn1_0/test_data_decomposed.csv', new_test_data, delimiter=',')
# Out:
# (4480, 96, 18)

# %%
from config import config
from models.MTCL_re import Model
model = Model(config)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
model.eval()
i = 555
# 将test_data输入到模型中，并将模型中的gates输出保存
x = test_data[i//128:i//128+128, :, :]
x = torch.from_numpy(x).float()
print(x.shape)
out, balance_loss, contrastive_loss = model(x)
print(out.shape)
layer_gates = []
for j in range(model.layer_nums):
    gates = model.AMS_lists[j].gates
    out_gate = gates[i%128-1, :]
    print(out_gate.shape)
    layer_gates.append(out_gate.detach().cpu().numpy())
# print(len(gates))
print(gates.shape)
print(test_data.shape)
print(len(layer_gates))
# 将layer_gates堆叠
out_layer_gates = np.vstack(layer_gates)
print(out_layer_gates.shape)
# 将layer_gates保存到csv文件中
np.savetxt('label_results/layer_gates_{}.csv'.format(i), out_layer_gates, delimiter=',')
# Out:
# torch.Size([128, 96, 18])
# torch.Size([128, 96, 18])
# torch.Size([2])
# torch.Size([2])
# torch.Size([2])
# torch.Size([128, 2])
# (4480, 96, 18)
# 3
# (3, 2)

# %%
print(out_layer_gates)
# Out:
# [[0.87489283 0.12510714]
#  [0.8882907  0.11170924]
#  [0.65779334 0.34220672]]
